# %% [markdown]
# ### 'Box Office numbers are significantly higher in the 2010s compared to 2000s'

# %%
import pandas as pd

# %%
pd.read_csv('./Data/visitors_per_year_and_movie.csv')
# Out:
#        Unnamed: 0         original title producing country  production year  \
# 0               0             Cinderella                US             1950
# 1               1           Broken Arrow                US             1950
# 2               2               Rashômon                JP             1950
# 3               3          All about Eve                US             1950
# 4               4         Das kalte Herz                DD             1950
# ...           ...                    ...               ...              ...
# 13664       13664    Nikdy nehovor nikdy                SK             2023
# 13665       13665        Como Dios manda                ES             2023
# 13666       13666  The Canterville Ghost                GB             2023
# 13667       13667       Haita de actiune                RO             2023
# 13668       13668    Nefes: Yer Eksi Iki                TR             2023
#
# ...
